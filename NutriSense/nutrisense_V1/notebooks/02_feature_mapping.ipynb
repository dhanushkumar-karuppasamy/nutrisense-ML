# %% [markdown]
# # 02. Feature Mapping
#
# The purpose of feature mapping is to map the original, cryptic NFHS survey variable codes (e.g., `v024`, `hv206`, `hw70`) to standardized, human-readable feature names (e.g., `state`, `electricity`, `stunting_target`). This ensures consistency and clarity across the data cleaning, analysis, and modeling stages of our project.

# %%
import os
import pandas as pd

# %%
# Load the standardized feature dictionary mapping original NFHS codes to target feature names
dict_path = r"F:\FinalYr Project\nutrisense\data\interim\feature_dictionary.csv"
df_dict = pd.read_csv(dict_path)

# %%
# Display the complete feature mapping dictionary
df_dict

# %% [markdown]
# > **Note:** All variable codes and category mapping rules must be verified against the dataset metadata before running final modeling to ensure correct mapping alignments.
